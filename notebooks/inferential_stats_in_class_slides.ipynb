# %% [markdown]
# ## Table Content
#
# - Basic Probability
# - Condition Probability
# - Normal Distribution
# - Central Limit Theorem
# - Hypothesis Testing
# - Tests
#     - Z-test
#     - T-test
#     - Chi-Square test
# - P-value and Confident Interval
# - Precision and Recall
# - Type I and Type II error

# %% [markdown]
# ## Basic Probability
#
# What are the chances that the newly given house is more or less than the average house price? How do we know the chance?
#
# So this is what we can look for, go for the probability that how many house have the price greater or less than the mean in given data and we can predict where the new house price will fall.
#
# Probability is the chance of occurrence of an event- how likely it is that some event will happen.
#
# Sometimes you can measure a probability with a number like "10% chance of rain", or you can use words such as impossible, unlikely, possible, even chance, likely and certain.
#
# ![Probability.PNG](attachment:Probability.PNG)

# %% [markdown]
# Simply put, probability describes what will happen in a given ideal world whereas statistics describes how ideal is the world.
#
# **Basic Definitions**
#
# **Experiment**: An operation that can produce some well defined outcomes.
#
# **Sample Space**: A sample space of an experiment is the set of all possible results of the experiment.
#
#         Example: In throwing a dice the possible results are: {1,2,3,4,5,6}
#
# **Sample Point**: just one of the possible outcomes.
#      Example: Deck of Cards: the King of Hearts is a sample point
#
# **Event**: An event is any group/subset of outcomes from the sample space.
#       Example: In throwing a dice the possibilities of an odd event are: {1,3,5}
#
# ![Probability-1.PNG](attachment:Probability-1.PNG)

# %%
import pandas as pd 
import numpy as np
data = pd.read_csv("C:/Users/Alex/Desktop/Greyatom/GA_extended_content/Data/house_pricing/train.csv")
Sales_price = pd.Series(data['SalePrice'])

mean = np.mean(Sales_price)
print('Mean = {0:.2f}'.format(mean))

X = Sales_price >= mean
Y = Sales_price <= mean

Probability_X = sum(X)/ len(Sales_price)
print('Their is a {0:.2f} chance that the new house will be greater than the mean'.format(Probability_X))

Probability_Y = sum(Y)/ len(Sales_price)
print('Their is a {0:.2f} chance that the new house will be less than the mean'.format(Probability_Y))
# Out:
# Mean = 180921.20
# Their is a 0.38 chance that the new house will be greater than the mean
# Their is a 0.62 chance that the new house will be less than the mean

# %% [markdown]
# So, now a new house will have 62% chance that it will be below the mean and 38% above the mean.
#
# ** Probability Rules **
# ![Probability_rules.PNG](attachment:Probability_rules.PNG)
#
# - Sample space is denoted by the area of rectangle. Since probability is associated with area it cannot be negative.
#
# - Two events are mutually exclusive/disjoint if they cannot occur simultaneously. The probability of two disjoint events to occur together is 0.
#
# Example: In a single coin toss it can either result in head or tails, but not both.

# %% [markdown]
# ![Probability_rules_1.PNG](attachment:Probability_rules_1.PNG)
#
# ![Probability_rules_2.PNG](attachment:Probability_rules_2.PNG)

# %% [markdown]
# Now, What if you have a data where you need to know the probability of building having bedroom more than three given that it is a two store building? How do you check ?
#
# One of the approach is using **Conditional Probability**, Where the two store building data is given and you need to known the probability of number of bedrooms greater than three.
#
# Conditional probability is the probability of an  event A occurring, given that B has already occurred.![CP_1.PNG](attachment:CP_1.PNG)
#
# ![CP_2.PNG](attachment:CP_2.PNG)

# %%
two_store_building = sum(data['HouseStyle'] == '2Story')
print('Two store building = {}'.format(two_store_building))

More_than_3_bedroom = sum(data['BedroomAbvGr'] > 3)
print('Apartment having more than three bedroom = {}'.format(More_than_3_bedroom))

Conditional_Probability = More_than_3_bedroom/two_store_building
print('so the Conditional_Probability that the apartment having bedroom more than three \
given that building is two store is {0:.2f}'.format(Conditional_Probability))
# Out:
# Two store building = 445
# Apartment having more than three bedroom = 242
# so the Conditional_Probability that the apartment having bedroom more than three given that building is two store is 0.54

# %% [markdown]
# Example: In a group of 90 sports car buyers, 40 bought alarm systems, 30 purchased bucket seats, and 20
# purchased an alarm system and bucket seats.
# If a car buyer chosen at random bought an alarm system, what is the probability they also bought bucket seats?
#
# ![CP_3.PNG](attachment:CP_3.PNG)
#
# **Step 1**: Figure out P(A). It’s given in the question as 40%, or 0.4.
#
# **Step 2**: Figure out P(A∩B). This is the intersection of A and B: both happening together. It’s given in the question 20 out of 100 buyers, or 0.2.
#
# **Step 3**: Insert your answers into the formula:
#
#     P(B|A) = P(A∩B) / P(A) = 0.2 / 0.3 = 0.66.
#
# The probability that a buyer bought bucket seats, given that they purchased an alarm system, is 66%.

# %% [markdown]
# Now we understood Probability and Condition Probablity, now if we have a large data and we need to know the variability of the data, how we going to check the variability of the data?
#
# So Basically we need to plot the data and need to check whether the data follows **Normal Distribution**(it's also called the Gaussian).

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.hist(data['SalePrice'])
# Out:
# (array([ 148.,  723.,  373.,  135.,   51.,   19.,    4.,    3.,    2.,    2.]),
#  array([  34900.,  106910.,  178920.,  250930.,  322940.,  394950.,
#          466960.,  538970.,  610980.,  682990.,  755000.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# So, In our data the Saleprice is not normally distributed, it is skew towards the left.  Generally a Normal distribution looks as below:
#
# ![ND_1.jpg](attachment:ND_1.jpg)
#
# The normal distribution exhibits the following characteristics.
#
# - It is a continuous distribution and is referred as the bell-shaped curve.
# - It is a symmetrical distribution about its mean.
# - It is asymptotic to the horizontal axis.
# - It is unimodal.
# - Area under the curve is 1.
# - The Normal Distribution has: Mean, Median, Mode
# - 50% of values less than the mean and 50% greater than the mean
# - 68% of values are within 1 standard deviation of the mean
# - 95% of values are within 2 standard deviations of the mean
# - 99.7% of values are within 3 standard deviations of the mean
#
#
# It ﬁts many human characteristics, such as height, weight, length, speed, IQ, scholastic achievement, and years of life expectancy, among others. Like their human counterparts, living things in nature,such as trees,animals,insects,and others,have many characteristics that are normally distributed.
#
# Many variables in business and industry also are normally distributed. Some examples of variables that could produce normally distributed measurements include the annual cost of household insurance, the cost per square foot of renting warehouse space, and managers’ satisfaction with support from ownership on a ﬁve-point scale.

# %% [markdown]
# whenever there is a large population, we use samples and check whether the sample mean of sample follows a normal distribution,especially as the sample sizes become larger.
# What would happen to the distribution of sample means if we studied populations with differently shaped distributions? The answer to that question is given in the central limit theorem.
#
# Central limit theorem tells that If samples of size n are drawn randomly from a population that has a mean of $\mu$ and a standard deviation of $\sigma$, the sample means, $\bar x$, are approximately normally distributed for sufﬁciently large sample sizes (n $=>$ 30) regardless of the shape of the population distribution. If the population is normally distributed, the sample means are normally distributed for any size sample.
#
# From mathematical expectation, it can be shown that the mean of the sample means is the population mean.
#
#
# $$ \mu_x = \mu $$
#
# and the standard deviation of the sample means (called the standard error of the mean) is the standard deviation of the population divided by the square root of the sample size.
#
# $$ \sigma_x = \frac{\sigma}{\sqrt{N}}$$
#
#
# ![CL-01.JPG](attachment:CL-01.JPG)
#
# The central limit theorem creates the potential for applying the normal distribution to many problems when sample size is sufﬁciently large. Sample means that have been computed for random samples drawn from normally distributed populations are normally distributed.
#
# Note in the bottom row for the normally distributed population that the sample means are normally distributed even for n = 2. Note also that with the other population distributions, the distribution of the sample means begins to approximate the normal curve asnbecomes larger.For all four distributions, the distribution of sample means is approximately normal for n = 30.
#
# ![CL-02.JPG](attachment:CL-02.JPG)

# %% [markdown]
# The central limit theorem states that sample means are normally distributed regardless of the shape of the population for large samples and for any sample size with normally distributed populations.Thus,sample means can be analyzed by using zscores.
#
# A z score represents the number of standard deviations a value (x) is above or below the mean of a set of numbers when the data are normally distributed. Using z scores allows translation of a value’s raw distance from the mean into units of standard deviations.
# - For Population
# $$ z =  \frac{x - \sigma}{\sigma} $$
#
# - For Sample
#
# $$ z =  \frac{x - \bar x}{\frac{\sigma}{\sqrt{N}}} $$
#
#
# For example, for a data set that is normally distributed with a mean of 50 and a standard deviation of 10,suppose a statistician wants to determine the z score for a value of 70. This value (x = 70) is 20 units above the mean, so the z value is
#
# $$ z =  \frac{70 - 50}{10} = +2.0 $$
#
# This zscore signiﬁes that the raw score of 70 is two standard deviations above the mean.
# ![CL-03.JPG](attachment:CL-03.JPG)

# %% [markdown]
# Sometimes, a business analyst already knows the value of a population parameter or has a good idea but would like to test to determine if the value has changed, if the value applies in other situations, or if the value is what other researchers say it is.
#
# In such cases, business researchers use hypothesis tests.
#
# In the hypothesis testing process, the known parameter is assumed to be true, data are gathered from random samples taken from the population, and the resulting data are analyzed to determine if the parameter value is still true or has changed in some way.
#
# Hypotheses are tentative explanations of a principle operating in nature.
#
# There are two parameter to set, first is the null hypothesis that states the “null” condition exists; that is, there is nothing new happening, the old theory is still true, the old standard is correct, and the system is in control.
# Second is the alternative hypothesis, on the other hand, states that the new theory is true, there are new standards, the system is out of control, and/or something is happening.

# %%
# We have saleprice which is skewed let transform using log

transform_df = np.log(data['SalePrice'])
plt.hist(transform_df)
# Out:
# (array([   5.,   12.,   54.,  184.,  470.,  400.,  220.,   90.,   19.,    6.]),
#  array([ 10.46024211,  10.7676652 ,  11.07508829,  11.38251138,
#          11.68993448,  11.99735757,  12.30478066,  12.61220375,
#          12.91962684,  13.22704994,  13.53447303]),
#  <a list of 10 Patch objects>)

# %%
# chec for the mean
transform_mean = np.mean(transform_df)
print('Mean is {0:.2f}'.format(transform_mean))

transform_sd = np.std(transform_df)
print('SD is {0:.2f}'.format(transform_sd))
# Out:
# Mean is 12.02
# SD is 0.40

# %% [markdown]
# So suppose we have more sample and the researchers will say that the mean of the population has changed, in order to prove it he use hypothesis tesing. So,
#
# New_mean $\bar x$ = 18.52
# old_mean $\mu$ = 12.02
# Confident Interval = 95%
# SD = 0.40
# N = 84
#
# $$ z =  \frac{\bar x - \mu}{\frac{\sigma}{\sqrt{N}}} $$
#
#
# By calculating for the Z score.

# %%
z_score = (18.52-12.02)/(0.40/np.sqrt(30))
z_score
# Out:
# 89.004915594589491

# %%
from scipy.stats import norm
p_values = scipy.stats.norm.sf(abs(z_score))*2
p_values
# Out:
# 0.0
